# %% [markdown]
# #  **Data Loading**

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
print(len(os.listdir('drive/My Drive/Colab Notebooks/A3_Dataset/dataset1/images_prepped_train')))
print(len(os.listdir('drive/My Drive/Colab Notebooks/A3_Dataset/dataset1/images_prepped_test')))
# Out:
# 367
# 101

# %%
print(len(os.listdir('drive/My Drive/Colab Notebooks/A3_Dataset/dataset1/annotations_prepped_train')))
print(len(os.listdir('drive/My Drive/Colab Notebooks/A3_Dataset/dataset1/annotations_prepped_test')))
# Out:
# 377
# 101

# %%
import os
import numpy as np
import cv2
from sklearn.model_selection import train_test_split
import albumentations as A

def load_data():
    # Step 1: Data Preprocessing
    image_dir = 'drive/My Drive/Colab Notebooks/A3_Dataset/dataset1/images_prepped_train'
    annotation_dir = 'drive/My Drive/Colab Notebooks/A3_Dataset/dataset1/annotations_prepped_train'
    image_size = (256, 256)  # Resize images to (256, 256)

    images = []
    annotations = []

    # Read and preprocess images and annotations
    for filename in os.listdir(image_dir):
        image_path = os.path.join(image_dir, filename)
        annotation_path = os.path.join(annotation_dir, filename)
        
        # Read and resize image
        image = cv2.imread(image_path)
        image = cv2.resize(image, image_size)
        image = image / 255.0  # Normalize pixel values between 0 and 1
        
        
        # Read and resize annotation
        annotation = cv2.imread(annotation_path, cv2.IMREAD_GRAYSCALE)
        annotation = cv2.resize(annotation, image_size)
        #annotation=cv2.cvtColor(annotation,cv2.COLOR_BGR2GRAY)
        
        images.append(image)
        annotations.append(annotation)

    # Step 2: Train-Test Split
    images_train, images_val, annotations_train, annotations_val = train_test_split(images, annotations, test_size=0.2, random_state=42)

    images_val = np.array(images_val)
    annotations_val= np.array(annotations_val)
    annotations_val = np.expand_dims(annotations_val, axis=-1)
    
    return images_train,images_val,annotations_train,annotations_val

# %%
import os
import numpy as np
import cv2
from sklearn.model_selection import train_test_split
import albumentations as A

def load_test_data():
    # Step 1: Data Preprocessing
    image_dir = 'drive/My Drive/Colab Notebooks/A3_Dataset/dataset1/images_prepped_test'
    annotation_dir = 'drive/My Drive/Colab Notebooks/A3_Dataset/dataset1/annotations_prepped_test'
    image_size = (256, 256)  # Resize images to (256, 256)

    images = []
    annotations = []

    # Read and preprocess images and annotations
    for filename in os.listdir(image_dir):
        image_path = os.path.join(image_dir, filename)
        annotation_path = os.path.join(annotation_dir, filename)
        
        # Read and resize image
        image = cv2.imread(image_path)
        image = cv2.resize(image, image_size)
        image = image / 255.0  # Normalize pixel values between 0 and 1
        
        # Read and resize annotation
        annotation = cv2.imread(annotation_path, cv2.IMREAD_GRAYSCALE)
        annotation = cv2.resize(annotation, image_size)
        
        images.append(image)
        annotations.append(annotation)

    # Step 2: Train-Test Split
    

    images = np.array(images)
    annotations= np.array(annotations)
    annotations = np.expand_dims(annotations, axis=-1)
    
    return images,annotations

# %% [markdown]
# # **Data Augmentation**

# %%
def augment_train_data(images_train,annotations_train):
  
  # Step 4: Data Augmentation (Optional)
    augmentation = A.Compose([
        A.HorizontalFlip(p=0.5),  # Randomly flip images horizontally with a probability of 0.5
        A.VerticalFlip(p=0.5),  # Randomly flip images vertically with a probability of 0.5
        A.RandomRotate90(p=0.5),  # Randomly rotate images by 90 degrees with a probability of 0.5
        A.RandomBrightnessContrast(p=0.2),  # Randomly adjust brightness and contrast of images with a probability of 0.2
        A.GaussianBlur(p=0.1),  # Apply Gaussian blur with a probability of 0.1
    ])

    # Apply augmentation to training images and annotations
    #augmented_images_train = []
    #augmented_annotations_train = []

    for i in range(0,len(images_train)):
      image = (images_train[i] * 255).astype(np.uint8)  # Convert image to uint8
      annotation = (annotations_train[i] * 255).astype(np.uint8)  # Convert annotation to uint8

      augmented = augmentation(image=image, mask=annotation)
      images_train.append(augmented['image'])
      annotations_train.append(augmented['mask'])

    # Step 3: Data Formatting
    images_train = np.array(images_train)
    annotations_train = np.array(annotations_train)
    annotations_train = np.expand_dims(annotations_train, axis=-1)

    #images_train.append(augmented_images_train)
    #annotations_train.append(augmented_annotations_train)
    return images_train, annotations_train

# %% [markdown]
# # **Displaying data samples**

# %%
import matplotlib.pyplot as plt

# Function to display images and annotations
def display_samples(images, annotations, num_samples):
    fig, axes = plt.subplots(nrows=num_samples, ncols=2, figsize=(12, 12))

    for i in range(num_samples):
        image = images[i]
        annotation = annotations[i]

        # Plot the image
        axes[i][0].imshow(image)
        axes[i][0].axis('off')
        axes[i][0].set_title('Image')

        # Plot the annotation mask
        axes[i][1].imshow(annotation.squeeze(), cmap='viridis')
        axes[i][1].axis('off')
        axes[i][1].set_title('Annotation')

    plt.tight_layout()
    plt.show()

# %%
# Display samples from the train dataset
display_samples(images_train, annotations_train, num_samples=6)

# %%
import torch
from torch.utils.data import Dataset, DataLoader


# Custom dataset class
class CustomDataset(Dataset):
    def __init__(self, images, annotations):
        self.images = images
        self.annotations = annotations

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image = self.images[idx]
        annotation = self.annotations[idx]
        return image, annotation

# Create augmented dataset
train_dataset = CustomDataset(images_train, annotations_train)
test_dataset = CustomDataset(images_val, annotations_val)

# Define batch size
batch_size = 16

# Create data loaders
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# # **Model Creation - Mobilenet base**

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate, Input
from tensorflow.keras.models import Model
from tensorflow.keras.applications import MobileNetV2


def conv_block(inputs, num_filters):

    x = Conv2D(num_filters, 3, padding="same")(inputs)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(num_filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    return x

def decoder_block(inputs, skip, num_filters):
    x = Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(inputs)
    x = Concatenate()([x, skip])
    x = conv_block(x, num_filters)
    return x

def mobilenet_base_unet(input_shape):    
    
    inputs = Input(shape=input_shape)

    #Pre-trained MobileNetV2
    encoder = MobileNetV2(include_top=False, weights="imagenet",
        input_tensor=inputs, alpha=1.4)

    #Encoder
    s1 = encoder.get_layer("input_1").output               
    s2 = encoder.get_layer("block_1_expand_relu").output    
    s3 = encoder.get_layer("block_3_expand_relu").output    
    s4 = encoder.get_layer("block_6_expand_relu").output    

    
    b1 = encoder.get_layer("block_13_expand_relu").output   

    #Decoder
    d1 = decoder_block(b1, s4, 512)                         
    d2 = decoder_block(d1, s3, 256)                         
    d3 = decoder_block(d2, s2, 128)                        
    d4 = decoder_block(d3, s1, 64)                          

    
    outputs = Conv2D(1, 1, padding="same", activation="sigmoid")(d4)

    model = Model(inputs, outputs, name="MobileNet_UNet")

    return model
#https://github.com/nikhilroxtomar/Semantic-Segmentation-Architecture/tree/main/TensorFlow

# %% [markdown]
# # **Evaluation metrics**

# %%
import keras.backend as K


# Calculating dice coefficient
def dice_coeff(y_true,y_pred,smooth=1):
  intersection=K.sum(y_true*y_pred,axis=[1,2,3])
  union=K.sum(y_true,axis=[1,2,3])+K.sum(y_pred,axis=[1,2,3])
  dice=K.mean((2.*intersection+smooth)/(union+smooth))
  return dice

# Calculating Sensitivty
def sensitivity(y_true,y_pred):
  TP=K.sum(K.round(K.clip(y_true*y_pred,0,1)))
  PP=K.sum(K.round(K.clip(y_true,0,1)))
  return TP/(PP+K.epsilon())

#Calculating Specificity
def specificity(y_true,y_pred):
  TN=K.sum(K.round(K.clip((1-y_true)*(1-y_pred),0,1)))
  NN=K.sum(K.round(K.clip((1-y_true),0,1)))
  return TN/(NN+K.epsilon())

# %% [markdown]
# ## **Pipeline**

# %%
images_train,images_val,annotations_train,annotations_val=load_data()
images_train, annotations_train=augment_train_data(images_train,annotations_train)

# %%
'''images_train = np.array(images_train)
annotations_train = np.array(annotations_train)
annotations_train = np.expand_dims(annotations_train, axis=-1)'''

# %%
annotations_val=annotations_val.astype(np.float)
annotations_train=annotations_train.astype(np.float)
# Out:
# <ipython-input-7-5b263a47a5f2>:1: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   annotations_val=annotations_val.astype(np.float)
# <ipython-input-7-5b263a47a5f2>:2: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   annotations_train=annotations_train.astype(np.float)

# %%
shape = (256,256, 3)
model = mobilenet_base_unet(shape)
model.summary()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Model: "MobileNet_UNet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  Conv1 (Conv2D)                 (None, 128, 128, 48  1296        ['input_1[0][0]']
#                                 )
#
#  bn_Conv1 (BatchNormalization)  (None, 128, 128, 48  192         ['Conv1[0][0]']
#                                 )
#
#  Conv1_relu (ReLU)              (None, 128, 128, 48  0           ['bn_Conv1[0][0]']
#                                 )
#
#  expanded_conv_depthwise (Depth  (None, 128, 128, 48  432        ['Conv1_relu[0][0]']
#  wiseConv2D)                    )
#
#  expanded_conv_depthwise_BN (Ba  (None, 128, 128, 48  192        ['expanded_conv_depthwise[0][0]']
#  tchNormalization)              )
#
#  expanded_conv_depthwise_relu (  (None, 128, 128, 48  0          ['expanded_conv_depthwise_BN[0][0
#  ReLU)                          )                                ]']
#
#  expanded_conv_project (Conv2D)  (None, 128, 128, 24  1152       ['expanded_conv_depthwise_relu[0]
#                                 )                                [0]']
#
#  expanded_conv_project_BN (Batc  (None, 128, 128, 24  96         ['expanded_conv_project[0][0]']
#  hNormalization)                )
#
#  block_1_expand (Conv2D)        (None, 128, 128, 14  3456        ['expanded_conv_project_BN[0][0]'
#                                 4)                               ]
#
#  block_1_expand_BN (BatchNormal  (None, 128, 128, 14  576        ['block_1_expand[0][0]']
#  ization)                       4)
#
#  block_1_expand_relu (ReLU)     (None, 128, 128, 14  0           ['block_1_expand_BN[0][0]']
#                                 4)
#
#  block_1_pad (ZeroPadding2D)    (None, 129, 129, 14  0           ['block_1_expand_relu[0][0]']
#                                 4)
#
#  block_1_depthwise (DepthwiseCo  (None, 64, 64, 144)  1296       ['block_1_pad[0][0]']
#  nv2D)
#
#  block_1_depthwise_BN (BatchNor  (None, 64, 64, 144)  576        ['block_1_depthwise[0][0]']
#  malization)
#
#  block_1_depthwise_relu (ReLU)  (None, 64, 64, 144)  0           ['block_1_depthwise_BN[0][0]']
#
#  block_1_project (Conv2D)       (None, 64, 64, 32)   4608        ['block_1_depthwise_relu[0][0]']
#
#  block_1_project_BN (BatchNorma  (None, 64, 64, 32)  128         ['block_1_project[0][0]']
#  lization)
#
#  block_2_expand (Conv2D)        (None, 64, 64, 192)  6144        ['block_1_project_BN[0][0]']
#
#  block_2_expand_BN (BatchNormal  (None, 64, 64, 192)  768        ['block_2_expand[0][0]']
#  ization)
#
#  block_2_expand_relu (ReLU)     (None, 64, 64, 192)  0           ['block_2_expand_BN[0][0]']
#
#  block_2_depthwise (DepthwiseCo  (None, 64, 64, 192)  1728       ['block_2_expand_relu[0][0]']
#  nv2D)
#
#  block_2_depthwise_BN (BatchNor  (None, 64, 64, 192)  768        ['block_2_depthwise[0][0]']
#  malization)
#
#  block_2_depthwise_relu (ReLU)  (None, 64, 64, 192)  0           ['block_2_depthwise_BN[0][0]']
#
#  block_2_project (Conv2D)       (None, 64, 64, 32)   6144        ['block_2_depthwise_relu[0][0]']
#
#  block_2_project_BN (BatchNorma  (None, 64, 64, 32)  128         ['block_2_project[0][0]']
#  lization)
#
#  block_2_add (Add)              (None, 64, 64, 32)   0           ['block_1_project_BN[0][0]',
#                                                                   'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)        (None, 64, 64, 192)  6144        ['block_2_add[0][0]']
#
#  block_3_expand_BN (BatchNormal  (None, 64, 64, 192)  768        ['block_3_expand[0][0]']
#  ization)
#
#  block_3_expand_relu (ReLU)     (None, 64, 64, 192)  0           ['block_3_expand_BN[0][0]']
#
#  block_3_pad (ZeroPadding2D)    (None, 65, 65, 192)  0           ['block_3_expand_relu[0][0]']
#
#  block_3_depthwise (DepthwiseCo  (None, 32, 32, 192)  1728       ['block_3_pad[0][0]']
#  nv2D)
#
#  block_3_depthwise_BN (BatchNor  (None, 32, 32, 192)  768        ['block_3_depthwise[0][0]']
#  malization)
#
#  block_3_depthwise_relu (ReLU)  (None, 32, 32, 192)  0           ['block_3_depthwise_BN[0][0]']
#
#  block_3_project (Conv2D)       (None, 32, 32, 48)   9216        ['block_3_depthwise_relu[0][0]']
#
#  block_3_project_BN (BatchNorma  (None, 32, 32, 48)  192         ['block_3_project[0][0]']
#  lization)
#
#  block_4_expand (Conv2D)        (None, 32, 32, 288)  13824       ['block_3_project_BN[0][0]']
#
#  block_4_expand_BN (BatchNormal  (None, 32, 32, 288)  1152       ['block_4_expand[0][0]']
#  ization)
#
#  block_4_expand_relu (ReLU)     (None, 32, 32, 288)  0           ['block_4_expand_BN[0][0]']
#
#  block_4_depthwise (DepthwiseCo  (None, 32, 32, 288)  2592       ['block_4_expand_relu[0][0]']
#  nv2D)
#
#  block_4_depthwise_BN (BatchNor  (None, 32, 32, 288)  1152       ['block_4_depthwise[0][0]']
#  malization)
#
#  block_4_depthwise_relu (ReLU)  (None, 32, 32, 288)  0           ['block_4_depthwise_BN[0][0]']
#
#  block_4_project (Conv2D)       (None, 32, 32, 48)   13824       ['block_4_depthwise_relu[0][0]']
#
#  block_4_project_BN (BatchNorma  (None, 32, 32, 48)  192         ['block_4_project[0][0]']
#  lization)
#
#  block_4_add (Add)              (None, 32, 32, 48)   0           ['block_3_project_BN[0][0]',
#                                                                   'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)        (None, 32, 32, 288)  13824       ['block_4_add[0][0]']
#
#  block_5_expand_BN (BatchNormal  (None, 32, 32, 288)  1152       ['block_5_expand[0][0]']
#  ization)
#
#  block_5_expand_relu (ReLU)     (None, 32, 32, 288)  0           ['block_5_expand_BN[0][0]']
#
#  block_5_depthwise (DepthwiseCo  (None, 32, 32, 288)  2592       ['block_5_expand_relu[0][0]']
#  nv2D)
#
#  block_5_depthwise_BN (BatchNor  (None, 32, 32, 288)  1152       ['block_5_depthwise[0][0]']
#  malization)
#
#  block_5_depthwise_relu (ReLU)  (None, 32, 32, 288)  0           ['block_5_depthwise_BN[0][0]']
#
#  block_5_project (Conv2D)       (None, 32, 32, 48)   13824       ['block_5_depthwise_relu[0][0]']
#
#  block_5_project_BN (BatchNorma  (None, 32, 32, 48)  192         ['block_5_project[0][0]']
#  lization)
#
#  block_5_add (Add)              (None, 32, 32, 48)   0           ['block_4_add[0][0]',
#                                                                   'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)        (None, 32, 32, 288)  13824       ['block_5_add[0][0]']
#
#  block_6_expand_BN (BatchNormal  (None, 32, 32, 288)  1152       ['block_6_expand[0][0]']
#  ization)
#
#  block_6_expand_relu (ReLU)     (None, 32, 32, 288)  0           ['block_6_expand_BN[0][0]']
#
#  block_6_pad (ZeroPadding2D)    (None, 33, 33, 288)  0           ['block_6_expand_relu[0][0]']
#
#  block_6_depthwise (DepthwiseCo  (None, 16, 16, 288)  2592       ['block_6_pad[0][0]']
#  nv2D)
#
#  block_6_depthwise_BN (BatchNor  (None, 16, 16, 288)  1152       ['block_6_depthwise[0][0]']
#  malization)
#
#  block_6_depthwise_relu (ReLU)  (None, 16, 16, 288)  0           ['block_6_depthwise_BN[0][0]']
#
#  block_6_project (Conv2D)       (None, 16, 16, 88)   25344       ['block_6_depthwise_relu[0][0]']
#
#  block_6_project_BN (BatchNorma  (None, 16, 16, 88)  352         ['block_6_project[0][0]']
#  lization)
#
#  block_7_expand (Conv2D)        (None, 16, 16, 528)  46464       ['block_6_project_BN[0][0]']
#
#  block_7_expand_BN (BatchNormal  (None, 16, 16, 528)  2112       ['block_7_expand[0][0]']
#  ization)
#
#  block_7_expand_relu (ReLU)     (None, 16, 16, 528)  0           ['block_7_expand_BN[0][0]']
#
#  block_7_depthwise (DepthwiseCo  (None, 16, 16, 528)  4752       ['block_7_expand_relu[0][0]']
#  nv2D)
#
#  block_7_depthwise_BN (BatchNor  (None, 16, 16, 528)  2112       ['block_7_depthwise[0][0]']
#  malization)
#
#  block_7_depthwise_relu (ReLU)  (None, 16, 16, 528)  0           ['block_7_depthwise_BN[0][0]']
#
#  block_7_project (Conv2D)       (None, 16, 16, 88)   46464       ['block_7_depthwise_relu[0][0]']
#
#  block_7_project_BN (BatchNorma  (None, 16, 16, 88)  352         ['block_7_project[0][0]']
#  lization)
#
#  block_7_add (Add)              (None, 16, 16, 88)   0           ['block_6_project_BN[0][0]',
#                                                                   'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)        (None, 16, 16, 528)  46464       ['block_7_add[0][0]']
#
#  block_8_expand_BN (BatchNormal  (None, 16, 16, 528)  2112       ['block_8_expand[0][0]']
#  ization)
#
#  block_8_expand_relu (ReLU)     (None, 16, 16, 528)  0           ['block_8_expand_BN[0][0]']
#
#  block_8_depthwise (DepthwiseCo  (None, 16, 16, 528)  4752       ['block_8_expand_relu[0][0]']
#  nv2D)
#
#  block_8_depthwise_BN (BatchNor  (None, 16, 16, 528)  2112       ['block_8_depthwise[0][0]']
#  malization)
#
#  block_8_depthwise_relu (ReLU)  (None, 16, 16, 528)  0           ['block_8_depthwise_BN[0][0]']
#
#  block_8_project (Conv2D)       (None, 16, 16, 88)   46464       ['block_8_depthwise_relu[0][0]']
#
#  block_8_project_BN (BatchNorma  (None, 16, 16, 88)  352         ['block_8_project[0][0]']
#  lization)
#
#  block_8_add (Add)              (None, 16, 16, 88)   0           ['block_7_add[0][0]',
#                                                                   'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)        (None, 16, 16, 528)  46464       ['block_8_add[0][0]']
#
#  block_9_expand_BN (BatchNormal  (None, 16, 16, 528)  2112       ['block_9_expand[0][0]']
#  ization)
#
#  block_9_expand_relu (ReLU)     (None, 16, 16, 528)  0           ['block_9_expand_BN[0][0]']
#
#  block_9_depthwise (DepthwiseCo  (None, 16, 16, 528)  4752       ['block_9_expand_relu[0][0]']
#  nv2D)
#
#  block_9_depthwise_BN (BatchNor  (None, 16, 16, 528)  2112       ['block_9_depthwise[0][0]']
#  malization)
#
#  block_9_depthwise_relu (ReLU)  (None, 16, 16, 528)  0           ['block_9_depthwise_BN[0][0]']
#
#  block_9_project (Conv2D)       (None, 16, 16, 88)   46464       ['block_9_depthwise_relu[0][0]']
#
#  block_9_project_BN (BatchNorma  (None, 16, 16, 88)  352         ['block_9_project[0][0]']
#  lization)
#
#  block_9_add (Add)              (None, 16, 16, 88)   0           ['block_8_add[0][0]',
#                                                                   'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)       (None, 16, 16, 528)  46464       ['block_9_add[0][0]']
#
#  block_10_expand_BN (BatchNorma  (None, 16, 16, 528)  2112       ['block_10_expand[0][0]']
#  lization)
#
#  block_10_expand_relu (ReLU)    (None, 16, 16, 528)  0           ['block_10_expand_BN[0][0]']
#
#  block_10_depthwise (DepthwiseC  (None, 16, 16, 528)  4752       ['block_10_expand_relu[0][0]']
#  onv2D)
#
#  block_10_depthwise_BN (BatchNo  (None, 16, 16, 528)  2112       ['block_10_depthwise[0][0]']
#  rmalization)
#
#  block_10_depthwise_relu (ReLU)  (None, 16, 16, 528)  0          ['block_10_depthwise_BN[0][0]']
#
#  block_10_project (Conv2D)      (None, 16, 16, 136)  71808       ['block_10_depthwise_relu[0][0]']
#
#  block_10_project_BN (BatchNorm  (None, 16, 16, 136)  544        ['block_10_project[0][0]']
#  alization)
#
#  block_11_expand (Conv2D)       (None, 16, 16, 816)  110976      ['block_10_project_BN[0][0]']
#
#  block_11_expand_BN (BatchNorma  (None, 16, 16, 816)  3264       ['block_11_expand[0][0]']
#  lization)
#
#  block_11_expand_relu (ReLU)    (None, 16, 16, 816)  0           ['block_11_expand_BN[0][0]']
#
#  block_11_depthwise (DepthwiseC  (None, 16, 16, 816)  7344       ['block_11_expand_relu[0][0]']
#  onv2D)
#
#  block_11_depthwise_BN (BatchNo  (None, 16, 16, 816)  3264       ['block_11_depthwise[0][0]']
#  rmalization)
#
#  block_11_depthwise_relu (ReLU)  (None, 16, 16, 816)  0          ['block_11_depthwise_BN[0][0]']
#
#  block_11_project (Conv2D)      (None, 16, 16, 136)  110976      ['block_11_depthwise_relu[0][0]']
#
#  block_11_project_BN (BatchNorm  (None, 16, 16, 136)  544        ['block_11_project[0][0]']
#  alization)
#
#  block_11_add (Add)             (None, 16, 16, 136)  0           ['block_10_project_BN[0][0]',
#                                                                   'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)       (None, 16, 16, 816)  110976      ['block_11_add[0][0]']
#
#  block_12_expand_BN (BatchNorma  (None, 16, 16, 816)  3264       ['block_12_expand[0][0]']
#  lization)
#
#  block_12_expand_relu (ReLU)    (None, 16, 16, 816)  0           ['block_12_expand_BN[0][0]']
#
#  block_12_depthwise (DepthwiseC  (None, 16, 16, 816)  7344       ['block_12_expand_relu[0][0]']
#  onv2D)
#
#  block_12_depthwise_BN (BatchNo  (None, 16, 16, 816)  3264       ['block_12_depthwise[0][0]']
#  rmalization)
#
#  block_12_depthwise_relu (ReLU)  (None, 16, 16, 816)  0          ['block_12_depthwise_BN[0][0]']
#
#  block_12_project (Conv2D)      (None, 16, 16, 136)  110976      ['block_12_depthwise_relu[0][0]']
#
#  block_12_project_BN (BatchNorm  (None, 16, 16, 136)  544        ['block_12_project[0][0]']
#  alization)
#
#  block_12_add (Add)             (None, 16, 16, 136)  0           ['block_11_add[0][0]',
#                                                                   'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)       (None, 16, 16, 816)  110976      ['block_12_add[0][0]']
#
#  block_13_expand_BN (BatchNorma  (None, 16, 16, 816)  3264       ['block_13_expand[0][0]']
#  lization)
#
#  block_13_expand_relu (ReLU)    (None, 16, 16, 816)  0           ['block_13_expand_BN[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 32, 32, 512)  1671680    ['block_13_expand_relu[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 32, 32, 800)  0           ['conv2d_transpose[0][0]',
#                                                                   'block_6_expand_relu[0][0]']
#
#  conv2d (Conv2D)                (None, 32, 32, 512)  3686912     ['concatenate[0][0]']
#
#  batch_normalization (BatchNorm  (None, 32, 32, 512)  2048       ['conv2d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 32, 32, 512)  0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 32, 32, 512)  2359808     ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 32, 32, 512)  2048       ['conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 32, 32, 512)  0           ['batch_normalization_1[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 64, 64, 256)  524544     ['activation_1[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 64, 64, 448)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'block_3_expand_relu[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 64, 64, 256)  1032448     ['concatenate_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 64, 64, 256)  1024       ['conv2d_2[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 64, 64, 256)  0           ['batch_normalization_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 64, 64, 256)  590080      ['activation_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 64, 64, 256)  1024       ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 64, 64, 256)  0           ['batch_normalization_3[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 128, 128, 12  131200     ['activation_3[0][0]']
#  spose)                         8)
#
#  concatenate_2 (Concatenate)    (None, 128, 128, 27  0           ['conv2d_transpose_2[0][0]',
#                                 2)                                'block_1_expand_relu[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 128, 128, 12  313472      ['concatenate_2[0][0]']
#                                 8)
#
#  batch_normalization_4 (BatchNo  (None, 128, 128, 12  512        ['conv2d_4[0][0]']
#  rmalization)                   8)
#
#  activation_4 (Activation)      (None, 128, 128, 12  0           ['batch_normalization_4[0][0]']
#                                 8)
#
#  conv2d_5 (Conv2D)              (None, 128, 128, 12  147584      ['activation_4[0][0]']
#                                 8)
#
#  batch_normalization_5 (BatchNo  (None, 128, 128, 12  512        ['conv2d_5[0][0]']
#  rmalization)                   8)
#
#  activation_5 (Activation)      (None, 128, 128, 12  0           ['batch_normalization_5[0][0]']
#                                 8)
#
#  conv2d_transpose_3 (Conv2DTran  (None, 256, 256, 64  32832      ['activation_5[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 256, 256, 67  0           ['conv2d_transpose_3[0][0]',
#                                 )                                 'input_1[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 256, 256, 64  38656       ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_6 (BatchNo  (None, 256, 256, 64  256        ['conv2d_6[0][0]']
#  rmalization)                   )
#
#  activation_6 (Activation)      (None, 256, 256, 64  0           ['batch_normalization_6[0][0]']
#                                 )
#
#  conv2d_7 (Conv2D)              (None, 256, 256, 64  36928       ['activation_6[0][0]']
#                                 )
#
#  batch_normalization_7 (BatchNo  (None, 256, 256, 64  256        ['conv2d_7[0][0]']
#  rmalization)                   )
#
#  activation_7 (Activation)      (None, 256, 256, 64  0           ['batch_normalization_7[0][0]']
#                                 )
#
#  conv2d_8 (Conv2D)              (None, 256, 256, 1)  65          ['activation_7[0][0]']
#
# ==================================================================================================
# Total params: 11,753,809
# Trainable params: 11,725,617
# Non-trainable params: 28,192
# __________________________________________________________________________________________________

# %%
# !pip install -U -q segmentation-models
# !pip install -q tensorflow==2.2.1
# !pip install -q keras==2.5
import os
os.environ["SM_FRAMEWORK"] = "tf.keras"

from tensorflow import keras
import segmentation_models as sm
# Out:
# ERROR: Could not find a version that satisfies the requirement tensorflow==2.2.1 (from versions: 2.8.0rc0, 2.8.0rc1, 2.8.0, 2.8.1, 2.8.2, 2.8.3, 2.8.4, 2.9.0rc0, 2.9.0rc1, 2.9.0rc2, 2.9.0, 2.9.1, 2.9.2, 2.9.3, 2.10.0rc0, 2.10.0rc1, 2.10.0rc2, 2.10.0rc3, 2.10.0, 2.10.1, 2.11.0rc0, 2.11.0rc1, 2.11.0rc2, 2.11.0, 2.11.1, 2.12.0rc0, 2.12.0rc1, 2.12.0, 2.13.0rc0)
# ERROR: No matching distribution found for tensorflow==2.2.1
# ERROR: Could not find a version that satisfies the requirement keras==2.5 (from versions: 0.2.0, 0.3.0, 0.3.1, 0.3.2, 0.3.3, 1.0.0, 1.0.1, 1.0.2, 1.0.3, 1.0.4, 1.0.5, 1.0.6, 1.0.7, 1.0.8, 1.1.0, 1.1.1, 1.1.2, 1.2.0, 1.2.1, 1.2.2, 2.0.0, 2.0.1, 2.0.2, 2.0.3, 2.0.4, 2.0.5, 2.0.6, 2.0.7, 2.0.8, 2.0.9, 2.1.0, 2.1.1, 2.1.2, 2.1.3, 2.1.4, 2.1.5, 2.1.6, 2.2.0, 2.2.1, 2.2.2, 2.2.3, 2.2.4, 2.2.5, 2.3.0, 2.3.1, 2.4.0, 2.4.1, 2.4.2, 2.4.3, 2.5.0rc0, 2.6.0rc0, 2.6.0rc1, 2.6.0rc2, 2.6.0rc3, 2.6.0, 2.7.0rc0, 2.7.0rc2, 2.7.0, 2.8.0rc0, 2.8.0rc1, 2.8.0, 2.9.0rc0, 2.9.0rc1, 2.9.0rc2, 2.9.0, 2.10.0rc0, 2.10.0rc1, 2.10.0, 2.11.0rc0, 2.11.0rc1, 2.11.0rc2, 2.11.0rc3, 2.11.0, 2.12.0rc0, 2.12.0rc1, 2.12.0, 2.13.1rc0)
# ERROR: No matching distribution found for keras==2.5
# Segmentation Models: using `tf.keras` framework.

# %%
model.compile(optimizer='adam',
              loss=sm.losses.categorical_crossentropy,
              metrics=['accuracy'])

# %% [markdown]
# ## **Training**

# %%
batch_size=32
# Create a callback that saves the model's weights
cp_callback  = tf.keras.callbacks.ModelCheckpoint(filepath="drive/My Drive/Colab Notebooks/A3_Dataset/checkpoints/base1_{epoch:03d}.ckpt",save_weights_only=True,save_freq=4*batch_size)

# %%
output=model.fit(x=images_train,y=annotations_train,batch_size=32,epochs=5,verbose=1,validation_data=(images_val,annotations_val),callbacks=[cp_callback])
# Out:
# Epoch 1/5
# 10/10 [==============================] - 1557s 153s/step - loss: 3.5969e-07 - accuracy: 0.2306 - val_loss: 3.5094e-07 - val_accuracy: 0.2449
# Epoch 2/5

# %%
output=model.fit(x=images_train,y=annotations_train,batch_size=32,epochs=1,verbose=1,validation_data=(images_val,annotations_val),callbacks=[cp_callback])
# Out:
# 10/10 [==============================] - 1558s 154s/step - loss: 3.5969e-07 - accuracy: 0.1914 - val_loss: 3.5094e-07 - val_accuracy: 0.2651

# %% [markdown]
# ## **Graphs**

# %%
def plot_class_result():
  epochs = range(0,15)
  train_acc = output.history['accuracy']
  val_acc = output.history['val_accuracy']

  plt.plot(epochs, train_acc, 'r',label='Training accuracy')
  plt.plot(epochs, val_acc, 'black',label='validation accuracy')
  plt.title('Training and Validation accuracy for Labels')
  plt.xlabel('Epochs')
  plt.ylabel('Accuracy')
  plt.legend()
  plt.show()

# %%
plot_class_result()

# %% [markdown]
# ## **Testing**

# %%
test_images,test_labels=load_test_data()

print(test_images.shape)
print(test_labels.shape)
# Out:
# (101, 256, 256, 3)
# (101, 256, 256, 1)

# %%
label=model.predict(test_images)
test_labels=test_labels.astype(np.float)
acc=model.evaluate(test_images,test_labels)
# Out:
# 4/4 [==============================] - 141s 32s/step
# <ipython-input-17-a873cfd28dae>:2: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   test_labels=test_labels.astype(np.float)
# 4/4 [==============================] - 140s 31s/step - loss: 3.7880e-07 - accuracy: 0.2356

# %% [markdown]
# ## **Quantitative Results**

# %%
test_labels2=test_labels.astype(np.double)
label2=label.astype(np.double)

# %%
#Dice coefficient
d=dice_coeff(test_labels2,label2)
print("dice coefficient", d,"\n")


# Sensitivity
s=sensitivity(test_labels2,label2)
print("sensitivity",s,"\n")

# Specificity
sp=specificity(test_labels2,label2)
print("specificity",sp)
# Out:
# dice coefficient tf.Tensor(0.9055534890458533, shape=(), dtype=float64)
#
# sensitivity tf.Tensor(0.9124204535380781, shape=(), dtype=float64)
#
# specificity tf.Tensor(0.6446082466259513, shape=(), dtype=float64)

# %% [markdown]
# ## **Qualitative Results**

# %%
import matplotlib.pyplot as plt

n=1

#displaying test image
plt.imshow(test_images[1])

# %%
#display ground truth
plt.imshow(test_labels[n].squeeze(), cmap='viridis')

# %%
#ground truth superimposed on original image
fig, ax = plt.subplots()
ax.imshow(test_images[n])
ax.imshow(test_labels[n], alpha=0.5)
fig.show()

# %%
#predicted mask
plt.imshow(label[n],alpha=0.8)

# %%
#predicted mask superimposed on original image
fig, ax = plt.subplots()
ax.imshow(test_images[n])
ax.imshow(label[n], alpha=0.5)
fig.show()
